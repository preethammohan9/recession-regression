# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_input = pd.read_csv('../Input_features_1960_no_covid.csv')
df_input['Month'] = pd.to_datetime(df_input['Month'])
df_input
# Out:
#      Unnamed: 0.1  Unnamed: 0      Month  Fedfund_rate   GDP_pch  CPI_pc1  \
# 0               0           0 1960-01-01          3.99  2.657590  1.24095
# 1               1           1 1960-02-01          3.97  1.675410  1.41379
# 2               2           2 1960-03-01          3.84  0.693230  1.51881
# 3               3           3 1960-04-01          3.92 -0.288950  1.93237
# 4               4           4 1960-05-01          3.85  0.086070  1.82507
# ..            ...         ...        ...           ...       ...      ...
# 756           760         760 2023-05-01          5.06  1.310517  4.12884
# 757           761         761 2023-06-01          5.08  1.690863  3.09200
# 758           762         762 2023-07-01          5.12  2.071210  3.29908
# 759           763         763 2023-08-01          5.33  2.071210  3.70750
# 760           764         764 2023-09-01          5.33  2.071210  3.68990
#
#      Loan_pch  House_ch
# 0        10.2    -197.0
# 1        10.1    -164.0
# ...

# %%
df_output = pd.read_csv('../Employment_pch_1960_no_covid.csv')
df_output['Month'] = pd.to_datetime(df_output['Month'])

# %%
plt.plot(df_output['Month'], df_output['Total_private_pch'])
plt.xlabel('Time (Year)')
plt.ylabel('Eployment percentage change (%)')
# Out:
# Text(0, 0.5, 'Eployment percentage change (%)')

# %%
plt.plot(df_input['Month'], df_input['Loan_pch'], label = 'Consumer Loan', linestyle = ':', color = 'gray')
plt.plot(df_input['Month'], df_input['GDP_pch'], label = 'GDP', color = 'green')
plt.plot(df_input['Month'], df_input['CPI_pc1'], label = 'CPI', color = 'orange')
plt.legend()
plt.xlabel('Time (Year)')
plt.ylabel('Percentage change (%)')
# Out:
# Text(0, 0.5, 'Percentage change (%)')
